# %% [markdown]
# <a href="https://colab.research.google.com/github/anggitwr/LeavesImage-Classification/blob/main/vgg19_dari_16_label_Klasifikasi_tanaman_ep45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os
from matplotlib import image, pyplot
import pandas as pd
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip Compress File
zip_file_path = "./drive/MyDrive/klasifikasi/DATASET TANAMAN HERBAL5.zip"  # Replace with the actual path to your ZIP file
destination_dir = "./data/"  # Replace with the desired path to create the directory

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Extract the contents of the ZIP file to the destination directory
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_dir)

# %%
# Declaration file location
sdir = './data/DATASET TANAMAN HERBAL5/Data Training/'
labels = os.listdir(sdir)

# %%
filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths           labels
# 0  ./data/DATASET TANAMAN HERBAL5/Data Training/D...  Daun Jambu Biji
# 1  ./data/DATASET TANAMAN HERBAL5/Data Training/D...  Daun Jambu Biji
# 2  ./data/DATASET TANAMAN HERBAL5/Data Training/D...  Daun Jambu Biji
# 3  ./data/DATASET TANAMAN HERBAL5/Data Training/D...  Daun Jambu Biji
# 4  ./data/DATASET TANAMAN HERBAL5/Data Training/D...  Daun Jambu Biji
# Daun Kemangi       169
# Daun Sirsak        158
# Teh Hijau          156
# Lidah Buaya        155
# Daun Jambu Biji    154
# Daun Kunyit        154
# Daun Mint          151
# Kaca               146
# Plastik            144
# Kain               142
# Daun Pepaya        140
# Daun Kari          136
# Daun Sirih         136
# Kertas             136
# Besi               131
# Kardus             112
# Name: labels, dtype: int64

# %%
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
# from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import seaborn as sns
sns.set_style('darkgrid')
# from sklearn.metrics import confusion_matrix, classification_report
# from IPython.display import display, HTML
from keras.callbacks import EarlyStopping
# from tensorflow.keras.optimizers import RMSprop

# %%
train_split=.8
test_split=.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  1856   test_df length:  232   valid_df length:  232

# %%
height=224
width=224
channels=3
batch_size=64

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(rescale=1./255,
                       horizontal_flip=True,
                       vertical_flip=True,
                       rotation_range=50,
                       width_shift_range=0.1,
                       height_shift_range=0.1,
                       fill_mode='reflect',
                       brightness_range=(0.8,1.2),
                       zoom_range=0.2,
                      )
train_gen=gen.flow_from_dataframe( train_df,
                                  x_col='filepaths',
                                  y_col='labels',
                                  target_size=img_size,
                                  class_mode='categorical',
                                  color_mode='rgb',
                                  shuffle=True,
                                  batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255,
                            horizontal_flip=True,
                            vertical_flip=True,
                           )
valid_gen=validgen.flow_from_dataframe( valid_df,
                                       x_col='filepaths',
                                       y_col='labels',
                                       target_size=img_size,
                                       class_mode='categorical',
                                       color_mode='rgb',
                                       shuffle=True,
                                       batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255,
                          shear_range=0.2,
                          zoom_range=0.1,
                          horizontal_flip=True,
                          )
test_gen=testgen.flow_from_dataframe( test_df,
                                     x_col='filepaths',
                                     y_col='labels',
                                     target_size=img_size,
                                     class_mode='categorical',
                                     color_mode='rgb',
                                     shuffle=False,
                                     batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  58   test steps:  4
# Found 1849 validated image filenames belonging to 16 classes.
# Found 231 validated image filenames belonging to 16 classes.
# Found 232 validated image filenames belonging to 16 classes.
# ['Besi', 'Daun Jambu Biji', 'Daun Kari', 'Daun Kemangi', 'Daun Kunyit', 'Daun Mint', 'Daun Pepaya', 'Daun Sirih', 'Daun Sirsak', 'Kaca', 'Kain', 'Kardus', 'Kertas', 'Lidah Buaya', 'Plastik', 'Teh Hijau']
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 7 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen)
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<20:
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
base_model=tf.keras.applications.VGG19(include_top=False, weights="imagenet",input_tensor=Input(shape=(224,224,3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 5s 0us/step

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name= 'Anggit'
print("Building model with", base_model)
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Conv2D(filters=32,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.MaxPool2D(pool_size= 2, strides= 2),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.MaxPool2D(pool_size= 2, strides= 2),
    tf.keras.layers.Conv2D(filters=128,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(16, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')
# Out:
# Building model with <keras.engine.functional.Functional object at 0x7a0440fa3f10>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  conv2d (Conv2D)             (None, 7, 7, 32)          147488
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 3, 3, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 128)         73856
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dense_1 (Dense)             (None, 16)                8208
#
# =================================================================
# Total params: 20,412,336
# Trainable params: 387,952
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
epochs = 45
history = model.fit(x=train_gen, epochs = epochs, validation_data = valid_gen)
# Out:
# Epoch 1/45
# 29/29 [==============================] - 327s 10s/step - loss: 2.6868 - accuracy: 0.0800 - val_loss: 2.3271 - val_accuracy: 0.1472
# Epoch 2/45
# 29/29 [==============================] - 264s 9s/step - loss: 2.1608 - accuracy: 0.2185 - val_loss: 1.8146 - val_accuracy: 0.3203
# Epoch 3/45
# 29/29 [==============================] - 268s 9s/step - loss: 1.6471 - accuracy: 0.3737 - val_loss: 1.2523 - val_accuracy: 0.5411
# Epoch 4/45
# 29/29 [==============================] - 261s 9s/step - loss: 1.4024 - accuracy: 0.4505 - val_loss: 1.0588 - val_accuracy: 0.6234
# Epoch 5/45
# 29/29 [==============================] - 266s 9s/step - loss: 1.2089 - accuracy: 0.5349 - val_loss: 0.9284 - val_accuracy: 0.6580
# Epoch 6/45
# 29/29 [==============================] - 266s 9s/step - loss: 1.1004 - accuracy: 0.5792 - val_loss: 0.8909 - val_accuracy: 0.6797
# Epoch 7/45
# 29/29 [==============================] - 264s 9s/step - loss: 1.0299 - accuracy: 0.6149 - val_loss: 0.8491 - val_accuracy: 0.7143
# Epoch 8/45
# 29/29 [==============================] - 261s 9s/step - loss: 0.9662 - accuracy: 0.6349 - val_loss: 0.8600 - val_accuracy: 0.6710
# Epoch 9/45
# 29/29 [==============================] - 263s 9s/step - loss: 0.8799 - accuracy: 0.6723 - val_loss: 0.6991 - val_accuracy: 0.7359
# Epoch 10/45
# 29/29 [==============================] - 257s 9s/step - loss: 0.8682 - accuracy: 0.6777 - val_loss: 0.7948 - val_accuracy: 0.7229
# Epoch 11/45
# 29/29 [==============================] - 260s 9s/step - loss: 0.8007 - accuracy: 0.7215 - val_loss: 0.6490 - val_accuracy: 0.7835
# Epoch 12/45
# 29/29 [==============================] - 277s 10s/step - loss: 0.7745 - accuracy: 0.7188 - val_loss: 0.7997 - val_accuracy: 0.7273
# Epoch 13/45
# 29/29 [==============================] - 257s 9s/step - loss: 0.7836 - accuracy: 0.7231 - val_loss: 0.6719 - val_accuracy: 0.7662
# Epoch 14/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.6930 - accuracy: 0.7534 - val_loss: 0.7056 - val_accuracy: 0.7489
# Epoch 15/45
# 29/29 [==============================] - 265s 9s/step - loss: 0.6522 - accuracy: 0.7783 - val_loss: 0.6645 - val_accuracy: 0.7965
# Epoch 16/45
# 29/29 [==============================] - 265s 9s/step - loss: 0.7169 - accuracy: 0.7588 - val_loss: 0.5407 - val_accuracy: 0.7879
# Epoch 17/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.5963 - accuracy: 0.7961 - val_loss: 0.4476 - val_accuracy: 0.8528
# Epoch 18/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.5656 - accuracy: 0.8145 - val_loss: 0.5303 - val_accuracy: 0.8182
# Epoch 19/45
# 29/29 [==============================] - 256s 9s/step - loss: 0.5672 - accuracy: 0.8048 - val_loss: 0.5311 - val_accuracy: 0.8095
# Epoch 20/45
# 29/29 [==============================] - 261s 9s/step - loss: 0.5686 - accuracy: 0.8188 - val_loss: 0.5502 - val_accuracy: 0.8052
# Epoch 21/45
# 29/29 [==============================] - 259s 9s/step - loss: 0.6012 - accuracy: 0.7999 - val_loss: 0.4180 - val_accuracy: 0.8788
# Epoch 22/45
# 29/29 [==============================] - 283s 10s/step - loss: 0.5557 - accuracy: 0.8183 - val_loss: 0.4507 - val_accuracy: 0.8528
# Epoch 23/45
# 29/29 [==============================] - 258s 9s/step - loss: 0.5417 - accuracy: 0.8204 - val_loss: 0.4996 - val_accuracy: 0.8398
# Epoch 24/45
# 29/29 [==============================] - 259s 9s/step - loss: 0.5020 - accuracy: 0.8345 - val_loss: 0.4023 - val_accuracy: 0.8528
# Epoch 25/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.4978 - accuracy: 0.8356 - val_loss: 0.3829 - val_accuracy: 0.8745
# Epoch 26/45
# 29/29 [==============================] - 258s 9s/step - loss: 0.4661 - accuracy: 0.8524 - val_loss: 0.4135 - val_accuracy: 0.8615
# Epoch 27/45
# 29/29 [==============================] - 260s 9s/step - loss: 0.4450 - accuracy: 0.8507 - val_loss: 0.3960 - val_accuracy: 0.8528
# Epoch 28/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.4683 - accuracy: 0.8442 - val_loss: 0.4203 - val_accuracy: 0.8571
# Epoch 29/45
# 29/29 [==============================] - 264s 9s/step - loss: 0.4573 - accuracy: 0.8529 - val_loss: 0.4211 - val_accuracy: 0.8571
# Epoch 30/45
# 29/29 [==============================] - 257s 9s/step - loss: 0.4527 - accuracy: 0.8551 - val_loss: 0.3555 - val_accuracy: 0.8918
# Epoch 31/45
# 29/29 [==============================] - 272s 9s/step - loss: 0.4176 - accuracy: 0.8632 - val_loss: 0.3631 - val_accuracy: 0.8788
# Epoch 32/45
# 29/29 [==============================] - 256s 9s/step - loss: 0.4064 - accuracy: 0.8659 - val_loss: 0.3632 - val_accuracy: 0.8831
# Epoch 33/45
# 29/29 [==============================] - 267s 9s/step - loss: 0.4431 - accuracy: 0.8578 - val_loss: 0.4484 - val_accuracy: 0.8485
# Epoch 34/45
# 29/29 [==============================] - 257s 9s/step - loss: 0.4305 - accuracy: 0.8643 - val_loss: 0.5863 - val_accuracy: 0.8095
# Epoch 35/45
# 29/29 [==============================] - 260s 9s/step - loss: 0.4020 - accuracy: 0.8734 - val_loss: 0.3765 - val_accuracy: 0.8918
# Epoch 36/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.3707 - accuracy: 0.8826 - val_loss: 0.3575 - val_accuracy: 0.8918
# Epoch 37/45
# 29/29 [==============================] - 257s 9s/step - loss: 0.3534 - accuracy: 0.8870 - val_loss: 0.3245 - val_accuracy: 0.8745
# Epoch 38/45
# 29/29 [==============================] - 264s 9s/step - loss: 0.3725 - accuracy: 0.8794 - val_loss: 0.4086 - val_accuracy: 0.8658
# Epoch 39/45
# 29/29 [==============================] - 259s 9s/step - loss: 0.3958 - accuracy: 0.8707 - val_loss: 0.3991 - val_accuracy: 0.8874
# Epoch 40/45
# 29/29 [==============================] - 260s 9s/step - loss: 0.3347 - accuracy: 0.8989 - val_loss: 0.4487 - val_accuracy: 0.8831
# Epoch 41/45
# 29/29 [==============================] - 278s 10s/step - loss: 0.3732 - accuracy: 0.8783 - val_loss: 0.3871 - val_accuracy: 0.8745
# Epoch 42/45
# 29/29 [==============================] - 256s 9s/step - loss: 0.3278 - accuracy: 0.8870 - val_loss: 0.3603 - val_accuracy: 0.8874
# Epoch 43/45
# 29/29 [==============================] - 259s 9s/step - loss: 0.3135 - accuracy: 0.8967 - val_loss: 0.5124 - val_accuracy: 0.8485
# Epoch 44/45
# 29/29 [==============================] - 262s 9s/step - loss: 0.4113 - accuracy: 0.8724 - val_loss: 0.4128 - val_accuracy: 0.8442
# Epoch 45/45
# 29/29 [==============================] - 258s 9s/step - loss: 0.3586 - accuracy: 0.8875 - val_loss: 0.4207 - val_accuracy: 0.8788

# %%
def plot_loss_curves(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    #plot
    plt.plot(epochs, loss, label = 'training_loss')
    plt.plot(epochs, val_loss, label = 'val_loss')
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.ylabel("value")
    plt.legend()

    plt.figure()
    plt.plot(epochs, accuracy, label = 'training_accuracy')
    plt.plot(epochs, val_accuracy, label = 'val_accuracy')
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.ylabel("value")
    plt.legend()

# %%
plot_loss_curves(history)

# %%
model.save('./drive/MyDrive/klasifikasi/modeldatalain16-5-epoch45-vgg19.h5')

# %%
model.save('.modeldatalain16-5-epoch35-vgg19.h5')

# %%
model = tf.keras.models.load_model('.modeldatalain16-5-epoch35-vgg19.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()
open("converted16_45_vgg19_5.tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 22). These functions will not be directly callable after loading.
# 20517368
