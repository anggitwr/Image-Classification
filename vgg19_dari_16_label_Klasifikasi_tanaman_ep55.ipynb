# %% [markdown]
# <a href="https://colab.research.google.com/github/anggitwr/LeavesImage-Classification/blob/main/vgg19_dari_16_label_Klasifikasi_tanaman_ep55.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os
from matplotlib import image, pyplot
import pandas as pd
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzip Compress File
zip_file_path = "./drive/MyDrive/klasifikasi/DATASET TANAMAN HERBAL5.zip"  # Replace with the actual path to your ZIP file
destination_dir = "./data/"  # Replace with the desired path to create the directory

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Extract the contents of the ZIP file to the destination directory
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_dir)

# %%
# Declaration file location
sdir = './data/DATASET TANAMAN HERBAL5/Data Training/'
labels = os.listdir(sdir)

# %%
filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths   labels
# 0  ./data/DATASET TANAMAN HERBAL5/Data Training/P...  Plastik
# 1  ./data/DATASET TANAMAN HERBAL5/Data Training/P...  Plastik
# 2  ./data/DATASET TANAMAN HERBAL5/Data Training/P...  Plastik
# 3  ./data/DATASET TANAMAN HERBAL5/Data Training/P...  Plastik
# 4  ./data/DATASET TANAMAN HERBAL5/Data Training/P...  Plastik
# Daun Kemangi       169
# Daun Sirsak        158
# Teh Hijau          156
# Lidah Buaya        155
# Daun Jambu Biji    154
# Daun Kunyit        154
# Daun Mint          151
# Kaca               146
# Plastik            144
# Kain               142
# Daun Pepaya        140
# Daun Kari          136
# Kertas             136
# Daun Sirih         136
# Besi               131
# Kardus             112
# Name: labels, dtype: int64

# %%
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
# from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import seaborn as sns
sns.set_style('darkgrid')
# from sklearn.metrics import confusion_matrix, classification_report
# from IPython.display import display, HTML
from keras.callbacks import EarlyStopping
# from tensorflow.keras.optimizers import RMSprop

# %%
train_split=.8
test_split=.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  1856   test_df length:  232   valid_df length:  232

# %%
height=224
width=224
channels=3
batch_size=64

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(rescale=1./255,
                       horizontal_flip=True,
                       vertical_flip=True,
                       rotation_range=50,
                       width_shift_range=0.1,
                       height_shift_range=0.1,
                       fill_mode='reflect',
                       brightness_range=(0.8,1.2),
                       zoom_range=0.2,
                      )
train_gen=gen.flow_from_dataframe( train_df,
                                  x_col='filepaths',
                                  y_col='labels',
                                  target_size=img_size,
                                  class_mode='categorical',
                                  color_mode='rgb',
                                  shuffle=True,
                                  batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255,
                            horizontal_flip=True,
                            vertical_flip=True,
                           )
valid_gen=validgen.flow_from_dataframe( valid_df,
                                       x_col='filepaths',
                                       y_col='labels',
                                       target_size=img_size,
                                       class_mode='categorical',
                                       color_mode='rgb',
                                       shuffle=True,
                                       batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255,
                          shear_range=0.2,
                          zoom_range=0.1,
                          horizontal_flip=True,
                          )
test_gen=testgen.flow_from_dataframe( test_df,
                                     x_col='filepaths',
                                     y_col='labels',
                                     target_size=img_size,
                                     class_mode='categorical',
                                     color_mode='rgb',
                                     shuffle=False,
                                     batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  58   test steps:  4
# Found 1851 validated image filenames belonging to 16 classes.
# Found 231 validated image filenames belonging to 16 classes.
# Found 230 validated image filenames belonging to 16 classes.
# ['Besi', 'Daun Jambu Biji', 'Daun Kari', 'Daun Kemangi', 'Daun Kunyit', 'Daun Mint', 'Daun Pepaya', 'Daun Sirih', 'Daun Sirsak', 'Kaca', 'Kain', 'Kardus', 'Kertas', 'Lidah Buaya', 'Plastik', 'Teh Hijau']
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 5 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py:1137: UserWarning: Found 2 invalid image filename(s) in x_col="filepaths". These filename(s) will be ignored.
#   warnings.warn(

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen)
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<20:
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
base_model=tf.keras.applications.VGG19(include_top=False, weights="imagenet",input_tensor=Input(shape=(224,224,3)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
base_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name= 'Anggit'
print("Building model with", base_model)
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Conv2D(filters=32,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.MaxPool2D(pool_size= 2, strides= 2),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Conv2D(filters=64,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.MaxPool2D(pool_size= 2, strides= 2),
    tf.keras.layers.Conv2D(filters=128,padding='same', kernel_size = 3, activation='relu', strides= 1),
    tf.keras.layers.Dropout(rate=0.5),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(16, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')
# Out:
# Building model with <keras.engine.functional.Functional object at 0x78917c13fa00>

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  conv2d (Conv2D)             (None, 7, 7, 32)          147488
#
#  max_pooling2d (MaxPooling2D  (None, 3, 3, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 3, 3, 64)          18496
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 1, 1, 128)         73856
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 512)               66048
#
#  dense_1 (Dense)             (None, 16)                8208
#
# =================================================================
# Total params: 20,412,336
# Trainable params: 387,952
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
epochs = 55
history = model.fit(x=train_gen, epochs = epochs, validation_data = valid_gen)
# Out:
# Epoch 1/55
# 29/29 [==============================] - 297s 9s/step - loss: 2.6829 - accuracy: 0.0783 - val_loss: 2.4852 - val_accuracy: 0.1039
# Epoch 2/55
# 29/29 [==============================] - 252s 9s/step - loss: 2.2185 - accuracy: 0.2085 - val_loss: 1.7462 - val_accuracy: 0.3636
# Epoch 3/55
# 29/29 [==============================] - 258s 9s/step - loss: 1.6764 - accuracy: 0.3630 - val_loss: 1.3802 - val_accuracy: 0.4632
# Epoch 4/55
# 29/29 [==============================] - 247s 9s/step - loss: 1.3883 - accuracy: 0.4506 - val_loss: 1.2243 - val_accuracy: 0.5152
# Epoch 5/55
# 29/29 [==============================] - 245s 8s/step - loss: 1.1972 - accuracy: 0.5370 - val_loss: 1.0725 - val_accuracy: 0.6061
# Epoch 6/55
# 29/29 [==============================] - 265s 9s/step - loss: 1.0932 - accuracy: 0.5770 - val_loss: 0.9583 - val_accuracy: 0.6364
# Epoch 7/55
# 29/29 [==============================] - 278s 10s/step - loss: 1.0081 - accuracy: 0.6299 - val_loss: 0.8033 - val_accuracy: 0.7316
# Epoch 8/55
# 29/29 [==============================] - 283s 10s/step - loss: 0.9033 - accuracy: 0.6699 - val_loss: 0.7667 - val_accuracy: 0.7186
# Epoch 9/55
# 29/29 [==============================] - 290s 10s/step - loss: 0.8659 - accuracy: 0.6937 - val_loss: 0.7592 - val_accuracy: 0.7706
# Epoch 10/55
# 29/29 [==============================] - 293s 10s/step - loss: 0.8200 - accuracy: 0.7072 - val_loss: 0.7493 - val_accuracy: 0.7532
# Epoch 11/55
# 29/29 [==============================] - 289s 10s/step - loss: 0.7492 - accuracy: 0.7310 - val_loss: 0.7428 - val_accuracy: 0.7013
# Epoch 12/55
# 29/29 [==============================] - 292s 10s/step - loss: 0.6983 - accuracy: 0.7661 - val_loss: 0.6284 - val_accuracy: 0.7792
# Epoch 13/55
# 29/29 [==============================] - 290s 10s/step - loss: 0.7016 - accuracy: 0.7488 - val_loss: 0.7789 - val_accuracy: 0.7835
# Epoch 14/55
# 29/29 [==============================] - 301s 10s/step - loss: 0.6550 - accuracy: 0.7801 - val_loss: 0.7304 - val_accuracy: 0.7403
# Epoch 15/55
# 29/29 [==============================] - 297s 10s/step - loss: 0.6379 - accuracy: 0.7753 - val_loss: 0.7560 - val_accuracy: 0.7359
# Epoch 16/55
# 29/29 [==============================] - 292s 10s/step - loss: 0.6067 - accuracy: 0.8017 - val_loss: 0.6815 - val_accuracy: 0.7446
# Epoch 17/55
# 29/29 [==============================] - 301s 10s/step - loss: 0.5946 - accuracy: 0.7990 - val_loss: 0.6141 - val_accuracy: 0.7792
# Epoch 18/55
# 29/29 [==============================] - 284s 10s/step - loss: 0.5834 - accuracy: 0.8125 - val_loss: 0.6607 - val_accuracy: 0.7922
# Epoch 19/55
# 29/29 [==============================] - 293s 10s/step - loss: 0.5234 - accuracy: 0.8212 - val_loss: 0.6860 - val_accuracy: 0.7922
# Epoch 20/55
# 29/29 [==============================] - 279s 10s/step - loss: 0.3831 - accuracy: 0.8860 - val_loss: 0.5649 - val_accuracy: 0.8442
# Epoch 41/55
# 29/29 [==============================] - 283s 10s/step - loss: 0.3194 - accuracy: 0.9076 - val_loss: 0.4821 - val_accuracy: 0.8571
# Epoch 42/55
# 29/29 [==============================] - 284s 10s/step - loss: 0.3292 - accuracy: 0.8990 - val_loss: 0.4900 - val_accuracy: 0.8485
# Epoch 43/55
# 29/29 [==============================] - 278s 10s/step - loss: 0.3107 - accuracy: 0.9033 - val_loss: 0.5119 - val_accuracy: 0.8658
# Epoch 44/55
# 29/29 [==============================] - 290s 10s/step - loss: 0.3106 - accuracy: 0.8984 - val_loss: 0.5326 - val_accuracy: 0.8442
# Epoch 45/55
# 29/29 [==============================] - 280s 10s/step - loss: 0.3093 - accuracy: 0.8979 - val_loss: 0.5093 - val_accuracy: 0.8442
# Epoch 46/55
# 29/29 [==============================] - 283s 10s/step - loss: 0.3470 - accuracy: 0.8898 - val_loss: 0.4160 - val_accuracy: 0.8442
# Epoch 47/55
# 29/29 [==============================] - 281s 10s/step - loss: 0.3506 - accuracy: 0.8876 - val_loss: 0.4959 - val_accuracy: 0.8615
# Epoch 48/55
# 29/29 [==============================] - 278s 10s/step - loss: 0.2873 - accuracy: 0.9082 - val_loss: 0.5624 - val_accuracy: 0.8528
# Epoch 49/55
# 29/29 [==============================] - 281s 10s/step - loss: 0.2872 - accuracy: 0.9125 - val_loss: 0.4708 - val_accuracy: 0.8788
# Epoch 50/55
# 29/29 [==============================] - 282s 10s/step - loss: 0.2988 - accuracy: 0.9055 - val_loss: 0.4365 - val_accuracy: 0.8615
# Epoch 51/55
# 29/29 [==============================] - 282s 10s/step - loss: 0.2838 - accuracy: 0.9103 - val_loss: 0.4902 - val_accuracy: 0.8701
# Epoch 52/55
# 29/29 [==============================] - 280s 10s/step - loss: 0.2968 - accuracy: 0.9152 - val_loss: 0.5340 - val_accuracy: 0.8658
# Epoch 53/55
# 29/29 [==============================] - 281s 10s/step - loss: 0.2864 - accuracy: 0.9173 - val_loss: 0.4814 - val_accuracy: 0.8701
# Epoch 54/55
# 29/29 [==============================] - 276s 10s/step - loss: 0.3555 - accuracy: 0.8947 - val_loss: 0.5097 - val_accuracy: 0.8528
# Epoch 55/55
# 29/29 [==============================] - 275s 10s/step - loss: 0.2695 - accuracy: 0.9130 - val_loss: 0.4896 - val_accuracy: 0.8615

# %%
def plot_loss_curves(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    epochs = range(len(history.history['loss']))

    #plot
    plt.plot(epochs, loss, label = 'training_loss')
    plt.plot(epochs, val_loss, label = 'val_loss')
    plt.title("Loss")
    plt.xlabel("epochs")
    plt.ylabel("value")
    plt.legend()

    plt.figure()
    plt.plot(epochs, accuracy, label = 'training_accuracy')
    plt.plot(epochs, val_accuracy, label = 'val_accuracy')
    plt.title("Accuracy")
    plt.xlabel("epochs")
    plt.ylabel("value")
    plt.legend()

# %%
plot_loss_curves(history)

# %%
model.save('./drive/MyDrive/klasifikasi/modeldatalain16-5-epoch55-vgg19.h5')

# %%
model.save('.modeldatalain16-5-epoch55-vgg19.h5')

# %%
model = tf.keras.models.load_model('.modeldatalain16-5-epoch55-vgg19.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

tflite_model = converter.convert()
open("converted16_55_vgg19_5.tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 22). These functions will not be directly callable after loading.
# 20517368
